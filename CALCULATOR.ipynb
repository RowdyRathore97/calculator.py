# %% [markdown]
# ## CALCULATION-------

# %%
from tkinter  import *
window=Tk()

def button_click(number):
    current = e2.get()
    e2.delete(0, END)
    e2.insert(0, str(current) + str(number))
    
def b1():
    e2.delete(0, END)

def t15():
    try:
        result = eval(e2.get())
        e2.delete(0, END)
        e2.insert(0, result)
    except:
        e2.delete(0, END)
        e2.insert(0, "Error")   



e1=Label(window, text="CALCULATOR")
e1.grid(row=0, column=0)

b1=Button(window,text="CLEAR",height=1,width=10,command=b1)
b1.grid(row=0,column=2)

e2_value=StringVar()
e2=Entry(window)
e2.grid(row=0, column=1)

t1=Button(window,text=1,height=1,width=10,command=lambda: button_click(1))
t1.grid(row=1,column=0)

t2=Button(window,text=2,height=1,width=10,command=lambda: button_click(2))
t2.grid(row=1,column=1)

t3=Button(window,text=3,height=1,width=10,command=lambda: button_click(3))
t3.grid(row=1,column=2)

t4=Button(window,text='+',height=1,width=10,command=lambda: button_click('+'))
t4.grid(row=1,column=3)

t5=Button(window,text=4,height=1,width=10,command=lambda: button_click(4))
t5.grid(row=2,column=0)

t6=Button(window,text=5,height=1,width=10,command=lambda: button_click(5))
t6.grid(row=2,column=1)

t7=Button(window,text=6,height=1,width=10,command=lambda: button_click(6))
t7.grid(row=2,column=2)

t8=Button(window,text='-',height=1,width=10,command=lambda: button_click('-'))
t8.grid(row=2,column=3)

t9=Button(window,text=7,height=1,width=10,command=lambda: button_click(7))
t9.grid(row=3,column=0)

t10=Button(window,text=8,height=1,width=10,command=lambda: button_click(8))
t10.grid(row=3,column=1)

t11=Button(window,text=9,height=1,width=10,command=lambda: button_click(9))
t11.grid(row=3,column=2)

t12=Button(window,text='*',height=1,width=10,command=lambda: button_click('*'))
t12.grid(row=3,column=3)

t13=Button(window,text='.',height=1,width=10,command=lambda: button_click('.'))
t13.grid(row=4,column=0)

t14=Button(window,text=0,height=1,width=10,command=lambda: button_click(0))
t14.grid(row=4,column=1)

t15=Button(window,text="=",height=1,width=10,command=t15)
t15.grid(row=4,column=2)

t16=Button(window,text='/',height=1,width=10,command=lambda: button_click('/'))
t16.grid(row=4,column=3)








window.mainloop()
